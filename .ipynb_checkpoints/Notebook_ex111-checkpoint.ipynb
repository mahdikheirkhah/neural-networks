# %%
import numpy as np

# %% [markdown]
# 1. Implement a the function `feedforward` of the class `Neuron` that takes as input the inputs (x1, x2) and that uses the attributes: the weights and the bias to return y:
#
#    ```
#    class Neuron:
#       def __init__(self, weight1, weight2, bias):
#          self.weights_1 = weight1
#          self.weights_2 = weight2
#          self.bias = bias
#
#       def feedforward(cls, x1, x2):
#          #TODO
#          return y
#
#
#    ```
#
# Note: if you are comfortable with matrix multiplication, feel free to vectorize the operations as done in the article.
#
# - [Resource 1](https://victorzhou.com/blog/intro-to-neural-networks/)

# %%
class Neuron:
    def __init__(self, weight1, weight2, bias):
        self.weights = np.array([weight1, weight2])
        self.bias = bias

    def feedforward(self, x1, x2):
        inputs = np.array([x1, x2])
        z = np.dot(self.weights, inputs) + self.bias
        y = 1 / (1 + np.exp(-z))
        return y

# %%
neuron = Neuron(0,1,4)
print(neuron.feedforward(2,3))
# Out:
# 0.9990889488055994
